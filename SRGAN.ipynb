# %% [markdown]
# # LR image 放大4倍

# %%
import keras
import numpy as np
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Discriminator
# ![SRGAN](https://github.com/deepak112/Keras-SRGAN/raw/master/Architecture_images/network.jpg)
#
# Discriminator <font color='#ff0000'>__非conditionalGAN__</font> (https://github.com/deepak112/Keras-SRGAN/blob/master/train.py 是一般GAN)

# %%
def conv_bn_relu(layer_in,filter_size,filters,stride):
    x=keras.layers.Conv2D(filters,(filter_size,filter_size),strides=stride,padding='same')(layer_in)
    x=keras.layers.BatchNormalization(momentum=0.5)(x)
    x=keras.layers.LeakyReLU(alpha=0.2)(x)
    return x

# %%
def discriminator(input_shape):
    input_SR=keras.models.Input(shape=input_shape)
    
    x=keras.layers.Conv2D(64,(3,3),strides=1,padding='same')(input_SR)
    x=keras.layers.LeakyReLU(alpha=0.2)(x)
    x=conv_bn_relu(x,3,64,2)
    x=conv_bn_relu(x,3,128,1)
    x=conv_bn_relu(x,3,128,2)
    x=conv_bn_relu(x,3,256,1)
    x=conv_bn_relu(x,3,256,2)
    x=conv_bn_relu(x,3,512,1)
    x=conv_bn_relu(x,3,512,2)
    x=keras.layers.Flatten()(x)
    x=keras.layers.Dense(1024)(x)
    x=keras.layers.LeakyReLU(alpha=0.2)(x)
    x=keras.layers.Dense(1)(x)
    x=keras.layers.Activation('sigmoid')(x)
    
    model=keras.models.Model(inputs=input_SR,outputs=x,name='discriminator')
    model.compile(loss='binary_crossentropy',optimizer=keras.optimizers.Adam(lr=0.0001,beta_1=0.9))
    return model

# %%
d_model=discriminator((384,384,3))
d_model.summary()
# Out:
# WARNING:tensorflow:From /home/dorawu/anaconda3/envs/tf2.0/lib/python3.6/site-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Model: "discriminator"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 384, 384, 3)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 384, 384, 64)      1792
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 384, 384, 64)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 192, 192, 64)      36928
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 192, 192, 64)      256
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 192, 192, 64)      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 192, 192, 128)     73856
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 192, 192, 128)     512
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 192, 192, 128)     0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 96, 96, 128)       147584
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 96, 96, 128)       512
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 96, 96, 128)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 96, 96, 256)       295168
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 96, 96, 256)       1024
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 96, 96, 256)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 48, 48, 256)       590080
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 48, 48, 256)       1024
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 48, 48, 256)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 48, 48, 512)       1180160
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 48, 48, 512)       2048
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 48, 48, 512)       0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 24, 24, 512)       2359808
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 24, 24, 512)       2048
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 24, 24, 512)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 294912)            0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              301990912
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 1025
# _________________________________________________________________
# activation_1 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 306,684,737
# Trainable params: 306,681,025
# Non-trainable params: 3,712
# _________________________________________________________________

# %% [markdown]
# # Generator

# %%
def residual_block(layer_in,filter_size,filters,stride):
    x=keras.layers.Conv2D(filters,(filter_size,filter_size),strides=stride,padding='same')(layer_in)
    x=keras.layers.BatchNormalization(momentum=0.5)(x)
    x=keras.layers.PReLU(shared_axes=[1,2])(x)
    x=keras.layers.Conv2D(filters,(filter_size,filter_size),strides=stride,padding='same')(x)
    x=keras.layers.BatchNormalization(momentum=0.5)(x)
    x=keras.layers.Add()([x,layer_in])
    return x

# %%
def upsampling_block(layer_in,filter_size,filters,stride):
    x=keras.layers.Conv2D(filters,(filter_size,filter_size),strides=stride,padding='same')(layer_in)
    x=keras.layers.UpSampling2D(size=2)(x)
    x=keras.layers.PReLU(shared_axes=[1,2])(x)
    return x

# %%
def generator(input_shape):
    input_LR=keras.models.Input(shape=input_shape)
    x=keras.layers.Conv2D(64,(9,9),strides=1,padding='same')(input_LR)
    x=keras.layers.PReLU(shared_axes=[1,2])(x)
    skip=x
    for i in range(16):
        x=residual_block(x,3,64,1)
    x=keras.layers.Conv2D(64,(3,3),strides=1,padding='same')(x)
    x=keras.layers.BatchNormalization(momentum=0.5)(x)
    x=keras.layers.Add()([x,skip])
    for i in range(2):
        x=upsampling_block(x,3,256,1)
    x=keras.layers.Conv2D(3,(9,9),strides=1,padding='same')(x)
    x=keras.layers.Activation('tanh')(x)
    
    model=keras.models.Model(inputs=input_LR,outputs=x,name='generator')
    return model

# %%
g_model=generator((96,96,3))
g_model.summary()
# Out:
# Model: "generator"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 96, 96, 3)    0
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 96, 96, 64)   15616       input_2[0][0]
# __________________________________________________________________________________________________
# p_re_lu_1 (PReLU)               (None, 96, 96, 64)   64          conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 96, 96, 64)   36928       p_re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 96, 96, 64)   256         conv2d_10[0][0]
# __________________________________________________________________________________________________
# p_re_lu_2 (PReLU)               (None, 96, 96, 64)   64          batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 96, 96, 64)   36928       p_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 96, 96, 64)   256         conv2d_11[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 96, 96, 64)   0           batch_normalization_9[0][0]
#                                                                  p_re_lu_1[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 96, 96, 64)   36928       add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 96, 96, 64)   256         conv2d_12[0][0]
# __________________________________________________________________________________________________
# p_re_lu_3 (PReLU)               (None, 96, 96, 64)   64          batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 96, 96, 64)   36928       p_re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 96, 96, 64)   256         conv2d_13[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 96, 96, 64)   0           batch_normalization_11[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 96, 96, 64)   36928       add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 96, 96, 64)   256         conv2d_14[0][0]
# __________________________________________________________________________________________________
# p_re_lu_4 (PReLU)               (None, 96, 96, 64)   64          batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 96, 96, 64)   36928       p_re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 96, 96, 64)   256         conv2d_15[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 96, 96, 64)   0           batch_normalization_13[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 96, 96, 64)   36928       add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 96, 96, 64)   256         conv2d_16[0][0]
# __________________________________________________________________________________________________
# p_re_lu_5 (PReLU)               (None, 96, 96, 64)   64          batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 96, 96, 64)   36928       p_re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 96, 96, 64)   256         conv2d_17[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 96, 96, 64)   0           batch_normalization_15[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 96, 96, 64)   36928       add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 96, 96, 64)   256         conv2d_18[0][0]
# __________________________________________________________________________________________________
# p_re_lu_6 (PReLU)               (None, 96, 96, 64)   64          batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 96, 96, 64)   36928       p_re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 96, 96, 64)   256         conv2d_19[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 96, 96, 64)   0           batch_normalization_17[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 96, 96, 64)   36928       add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 96, 96, 64)   256         conv2d_20[0][0]
# __________________________________________________________________________________________________
# p_re_lu_7 (PReLU)               (None, 96, 96, 64)   64          batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 96, 96, 64)   36928       p_re_lu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 96, 96, 64)   256         conv2d_21[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 96, 96, 64)   0           batch_normalization_19[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 96, 96, 64)   36928       add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 96, 96, 64)   256         conv2d_22[0][0]
# __________________________________________________________________________________________________
# p_re_lu_8 (PReLU)               (None, 96, 96, 64)   64          batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 96, 96, 64)   36928       p_re_lu_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 96, 96, 64)   256         conv2d_23[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 96, 96, 64)   0           batch_normalization_21[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 96, 96, 64)   36928       add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 96, 96, 64)   256         conv2d_24[0][0]
# __________________________________________________________________________________________________
# p_re_lu_9 (PReLU)               (None, 96, 96, 64)   64          batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 96, 96, 64)   36928       p_re_lu_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 96, 96, 64)   256         conv2d_25[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 96, 96, 64)   0           batch_normalization_23[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 96, 96, 64)   36928       add_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 96, 96, 64)   256         conv2d_26[0][0]
# __________________________________________________________________________________________________
# p_re_lu_10 (PReLU)              (None, 96, 96, 64)   64          batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 96, 96, 64)   36928       p_re_lu_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 96, 96, 64)   256         conv2d_27[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 96, 96, 64)   0           batch_normalization_25[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 96, 96, 64)   36928       add_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 96, 96, 64)   256         conv2d_28[0][0]
# __________________________________________________________________________________________________
# p_re_lu_11 (PReLU)              (None, 96, 96, 64)   64          batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 96, 96, 64)   36928       p_re_lu_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 96, 96, 64)   256         conv2d_29[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 96, 96, 64)   0           batch_normalization_27[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 96, 96, 64)   36928       add_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 96, 96, 64)   256         conv2d_30[0][0]
# __________________________________________________________________________________________________
# p_re_lu_12 (PReLU)              (None, 96, 96, 64)   64          batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 96, 96, 64)   36928       p_re_lu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 96, 96, 64)   256         conv2d_31[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 96, 96, 64)   0           batch_normalization_29[0][0]
#                                                                  add_10[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 96, 96, 64)   36928       add_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 96, 96, 64)   256         conv2d_32[0][0]
# __________________________________________________________________________________________________
# p_re_lu_13 (PReLU)              (None, 96, 96, 64)   64          batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 96, 96, 64)   36928       p_re_lu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 96, 96, 64)   256         conv2d_33[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 96, 96, 64)   0           batch_normalization_31[0][0]
#                                                                  add_11[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 96, 96, 64)   36928       add_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 96, 96, 64)   256         conv2d_34[0][0]
# __________________________________________________________________________________________________
# p_re_lu_14 (PReLU)              (None, 96, 96, 64)   64          batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 96, 96, 64)   36928       p_re_lu_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 96, 96, 64)   256         conv2d_35[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 96, 96, 64)   0           batch_normalization_33[0][0]
#                                                                  add_12[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 96, 96, 64)   36928       add_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 96, 96, 64)   256         conv2d_36[0][0]
# __________________________________________________________________________________________________
# p_re_lu_15 (PReLU)              (None, 96, 96, 64)   64          batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 96, 96, 64)   36928       p_re_lu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 96, 96, 64)   256         conv2d_37[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 96, 96, 64)   0           batch_normalization_35[0][0]
#                                                                  add_13[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 96, 96, 64)   36928       add_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 96, 96, 64)   256         conv2d_38[0][0]
# __________________________________________________________________________________________________
# p_re_lu_16 (PReLU)              (None, 96, 96, 64)   64          batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 96, 96, 64)   36928       p_re_lu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 96, 96, 64)   256         conv2d_39[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 96, 96, 64)   0           batch_normalization_37[0][0]
#                                                                  add_14[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 96, 96, 64)   36928       add_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 96, 96, 64)   256         conv2d_40[0][0]
# __________________________________________________________________________________________________
# p_re_lu_17 (PReLU)              (None, 96, 96, 64)   64          batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 96, 96, 64)   36928       p_re_lu_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 96, 96, 64)   256         conv2d_41[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 96, 96, 64)   0           batch_normalization_39[0][0]
#                                                                  add_15[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 96, 96, 64)   36928       add_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 96, 96, 64)   256         conv2d_42[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 96, 96, 64)   0           batch_normalization_40[0][0]
#                                                                  p_re_lu_1[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 96, 96, 256)  147712      add_17[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 192, 192, 256 0           conv2d_43[0][0]
# __________________________________________________________________________________________________
# p_re_lu_18 (PReLU)              (None, 192, 192, 256 256         up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 192, 192, 256 590080      p_re_lu_18[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 384, 384, 256 0           conv2d_44[0][0]
# __________________________________________________________________________________________________
# p_re_lu_19 (PReLU)              (None, 384, 384, 256 256         up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 384, 384, 3)  62211       p_re_lu_19[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 384, 384, 3)  0           conv2d_45[0][0]
# ==================================================================================================
# Total params: 2,044,291
# Trainable params: 2,040,067
# Non-trainable params: 4,224
# __________________________________________________________________________________________________

# %% [markdown]
# # Composite model
# ![SRGAN](https://1.bp.blogspot.com/-Y5bRR5aX4pI/XZMAuwcG5uI/AAAAAAAAEsQ/cDA7XKvQ-CIvNmXGk_SWb_Yg55hEFy5fQCLcBGAsYHQ/s1600/IMG_2377.JPG)
# 圖錯，代修正
# <font color='#00aa00'>__D的input只有一個(非conditionalGAN)__
# __vgg的input只有一個，vgg(HR)為ground_truth__  </font>

# %% [markdown]
# ### import vgg19

# %%
import ssl
from keras.applications.vgg19 import VGG19
ssl._create_default_https_context = ssl._create_unverified_context
vgg19=VGG19(include_top=False,weights='imagenet',input_shape=(384,384,3))
vgg=keras.models.Model(inputs=vgg19.input,outputs=vgg19.get_layer('block5_conv4').output,name='vgg')
vgg.trainable=False
#for layer in vgg.layers:
#    layer.trainable=False
vgg.summary()
# Out:
# Model: "vgg"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 384, 384, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 384, 384, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 384, 384, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 192, 192, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 192, 192, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 192, 192, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 96, 96, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 96, 96, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 96, 96, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 96, 96, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 96, 96, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 48, 48, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 48, 48, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 48, 48, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 48, 48, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 48, 48, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 24, 24, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 24, 24, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 24, 24, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 24, 24, 512)       2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 24, 24, 512)       2359808
# =================================================================
# Total params: 20,024,384
# Trainable params: 0
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %% [markdown]
# ### composite model = generator + discriminator + vgg19

# %%
def composite(g_model,d_model,input_shape_LR):
    d_model.trainable=False
    input_LR=keras.models.Input(shape=input_shape_LR)
    sr_out=g_model(input_LR)
    dis_out=d_model(sr_out)
    vgg_out=vgg(sr_out)
    model=keras.models.Model(inputs=input_LR,outputs=[dis_out,vgg_out],name='composite')
    model.compile(loss=['binary_crossentropy','mse'],optimizer=keras.optimizers.Adam(lr=0.0001,beta_1=0.9),
                  loss_weights=[1,1000])
    return model

# %%
c_model=composite(g_model,d_model,(96,96,3))
c_model.summary()
# Out:
# Model: "composite"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            (None, 96, 96, 3)    0
# __________________________________________________________________________________________________
# generator (Model)               (None, 384, 384, 3)  2044291     input_4[0][0]
# __________________________________________________________________________________________________
# discriminator (Model)           (None, 1)            306684737   generator[1][0]
# __________________________________________________________________________________________________
# vgg (Model)                     (None, 24, 24, 512)  20024384    generator[1][0]
# ==================================================================================================
# Total params: 328,753,412
# Trainable params: 2,040,067
# Non-trainable params: 326,713,345
# __________________________________________________________________________________________________

# %% [markdown]
# ### trainable
# 注意一下各個model的trainable屬性
# <font color='#ff0000'>__model trainable v.s. layer trainable:__</font> https://stackoverflow.com/questions/56675964/what-is-the-difference-between-setting-a-keras-model-trainable-vs-making-each-la/56682979#56682979?newreg=61cf9299fb974eb9999d473a9cac52ea

# %%
print(vgg.trainable)
print(vgg.layers[1].trainable)
print(vgg.layers)
# Out:
# False
# True
# [<keras.engine.input_layer.InputLayer object at 0x7f1638526c18>, <keras.layers.convolutional.Conv2D object at 0x7f1638526cf8>, <keras.layers.convolutional.Conv2D object at 0x7f1638526f28>, <keras.layers.pooling.MaxPooling2D object at 0x7f16384c0470>, <keras.layers.convolutional.Conv2D object at 0x7f16384c0668>, <keras.layers.convolutional.Conv2D object at 0x7f16384d2278>, <keras.layers.pooling.MaxPooling2D object at 0x7f16384e94a8>, <keras.layers.convolutional.Conv2D object at 0x7f16384e96d8>, <keras.layers.convolutional.Conv2D object at 0x7f16384f62e8>, <keras.layers.convolutional.Conv2D object at 0x7f163848d550>, <keras.layers.convolutional.Conv2D object at 0x7f163849d438>, <keras.layers.pooling.MaxPooling2D object at 0x7f16384b2320>, <keras.layers.convolutional.Conv2D object at 0x7f16384b2550>, <keras.layers.convolutional.Conv2D object at 0x7f163844b208>, <keras.layers.convolutional.Conv2D object at 0x7f163845d3c8>, <keras.layers.convolutional.Conv2D object at 0x7f163846d2b0>, <keras.layers.pooling.MaxPooling2D object at 0x7f1638406198>, <keras.layers.convolutional.Conv2D object at 0x7f16384063c8>, <keras.layers.convolutional.Conv2D object at 0x7f1638419ef0>, <keras.layers.convolutional.Conv2D object at 0x7f163842e240>, <keras.layers.convolutional.Conv2D object at 0x7f16383c2128>]

# %%
print(d_model.trainable)
print(g_model.trainable)
print(c_model.trainable)
# Out:
# False
# True
# True

# %% [markdown]
# # Fit

# %%
'''just like real_image_generator'''
def hr_image_generator(dataset,randi):
    HRs=dataset[randi]
    ones=np.ones((len(HRs),1))
    return HRs,ones

# %%
'''just like fake_image_generator'''
def sr_image_generator(g_model,dataset,randi):
    LRs=dataset[randi]
    SRs=g_model.predict(LRs)
    zeros=np.zeros((len(SRs),1))
    return SRs,zeros

# %%
def lr_image_egnerator(dataset,randi):
    LRs=dataset[randi]
    return LRs

# %%
'''vgg(HR),high level feature maps'''
def vgg_of_hr(HRs):
    return vgg.predict(HRs)

# %%
def fit(g_model,d_model,c_model,dataset_lr,dataset_hr,input_shape=(96,96,3),epochs=1000,batch_size=64):
    assert len(dataset_hr)==len(dataset_lr)
    batches=len(dataset_lr)//batch_size
    for epoch in range(1,epochs+1):
        for batch in range(1,batches+1):
            #fit discriminator
            randi=np.random.randint(0,len(dataset_lr),batch_size)  
            HRs,true_y=hr_image_generator(dataset_hr,randi)
            loss_hr=d_model.train_on_batch(HRs,true_y)
            SRs,false_y=sr_image_generator(g_model,dataset_lr,randi)
            loss_sr=d_model.train_on_batch(SRs,false_y)
            #fit generator
            randi=np.random.randint(0,len(dataset_lr),batch_size)
            LRs=lr_image_generator(dataset_lr,randi)
            HRs,true_y=hr_image_generator(dataset_hr,randi)
            loss_perceptual,_,_=c_model.train_on_batch(LRs,[true_y,vgg_of_hr(HRs)])
        print('epoch {}/{}: loss_hr:{:.2f} loss_sr:{:.2f} loss_perceptual:{:.2f}'.format(epoch,epochs,loss_hr,loss_sr,loss_perceptual))
        if epoch%10==0:
            summarize_performance(epoch,g_model,d_model,dataset_lr,dataset_hr)

# %%
def summarize_performance(epoch,g_model,d_model,dataset_lr,dataset_hr):
    #save model
    g_model.save('SRGAN//generator {}.h5'.format(epoch))
    d_model.save('SRGAN//discriminator {}.h5'.format(epoch))
    #save picture
    randi=np.random.randint(0,len(dataset_lr),5)
    LRs=lr_image_generator(dataset_lr,randi)
    SRs=sr_image_generator(g_model,dataset_lr,randi)
    HRs=hr_image_generator(dataset_hr,randi)
    SRs=(SRs+1)/2
    HRs=(HRs+1)/2
    plt.figure(figsize=(15,9))
    for i in range(5):
        plt.subplot(3,5,i+1)
        plt.imshow(LRs[i])
        plt.axis('off')
        plt.subplot(3,5,i+6)
        plt.imshow(SRs[i])
        plt.axis('off')
        plt.subplot(3,5,i+11)
        plt.imshow(HRs[i])
        plt.axis('off')
    plt.savefig('SRGAN//epoch {}.png'.format(epoch))
    plt.close()

# %% [markdown]
# # load dataset
# using the COCO(2014) dataset
# PIL <-> ndarray https://stackoverflow.com/questions/384759/how-to-convert-a-pil-image-into-a-numpy-array

# %%
import os
from PIL import Image
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import load_img
import matplotlib.pyplot as plt

# %% [raw]
# '''HR,LR,SR 範例,不重要'''
# image=Image.open('shetland-foal-pony.jpg')
# image_reshape=image.resize((384,384),Image.BICUBIC)
# image_reshape.save('HR_shetland-foal-pony.jpg')
# image_resize=image.resize((96,96),Image.BICUBIC)
# image_resize.save('LR_shetland-foal-pony.jpg')
# image_recover=image_resize.resize((384,384),Image.BICUBIC)
# image_recover.save('SR_shetland-foal-pony.jpg')

# %%
def load_image(path,lr_size=(96,96),hr_size=(384,384),pic=1000):
    #(None,96,96,3)
    LRs=[]
    #(None,384,384,3)
    HRs=[]
    i=0
    for filename in os.listdir(path):
        img=load_img(os.path.join(path,filename))
        if img.width<384 or img.height<384:
            continue
        img=img_to_array(load_img(os.path.join(path,filename),target_size=lr_size,interpolation='bicubic'),dtype='float')
        LRs.append(img)
        img=img_to_array(load_img(os.path.join(path,filename),target_size=hr_size,interpolation='bicubic'),dtype='float')
        HRs.append(img)
        i+=1
        if i>=pic:
            break
    return np.asarray(LRs),np.asarray(HRs)

# %% [markdown]
# ### save .npz with 800 images for training

# %% [raw]
# path='/home/dorawu/train2014'
# trainLR,trainHR=load_image(path,(96,96),(384,384),800)
# np.savez_compressed('SRGANtrainingset.npz',trainLR,trainHR)
# print('save:',trainLR.shape,trainHR.shape)

# %%
data=np.load('SRGANtrainingset.npz')
trainLR,trainHR=data['arr_0'],data['arr_1']
print(trainLR.shape,trainHR.shape)
# Out:
# (800, 96, 96, 3) (800, 384, 384, 3)

# %%
print(trainLR[0,:4,:4,:])
# Out:
# [[[34. 17. 10.]
#   [32. 16.  9.]
#   [27. 14.  7.]
#   [20. 10.  7.]]
#
#  [[34. 17. 10.]
#   [34. 18. 10.]
#   [30. 15.  8.]
#   [24. 12.  7.]]
#
#  [[34. 18. 10.]
#   [35. 19. 12.]
#   [34. 18. 11.]
#   [29. 15.  8.]]
#
#  [[36. 18. 11.]
#   [36. 18. 11.]
#   [27. 14.  8.]
#   [27. 16. 10.]]]

# %% [markdown]
# ### from \[0,255\] to \[-1,1\] or \[0,1\]
# Paper says LR be \[0,1\], HR be \[-1,1\]

# %%
trainLR=trainLR/255
trainHR=(trainHR-127.5)/127.5

# %%
#already define
#g_model=generator((96,96,3))
#d_model=discriminator((384,384,3))
#c_model=composite(g_model,d_model,(96,96,3))
fit(g_model,d_model,c_model,trainLR,trainHR,input_shape=(96,96,3),epochs=1000,batch_size=64)
# Out:
# /home/dorawu/anaconda3/envs/tf2.0/lib/python3.6/site-packages/keras/engine/training.py:297: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
